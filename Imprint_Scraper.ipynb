# %%
from bs4 import BeautifulSoup
import requests 
import re

# %%
class Scraper:
    def __init__(self):
        pass

    def __call__(self,url,print_scarps=False):
        page = requests.get(url)
        soup = BeautifulSoup(page.content,'html.parser')
        strips = list(soup.stripped_strings)
        print("URL :", url)
        if print_scarps:
            print("Strips: ",strips)
        print("Email: ",self.getEmail(strips))
        print("ZIP And Country: ",self.getZipAndCountry(strips))
        print("Telefon: ",self.getTelefonNumber(strips))

    def getEmail(self,strips):
        email_regex = r'[\w.+-]+@[\w-]+\.[\w.-]+'
        r = re.compile(email_regex)
        return list(filter(r.match, strips))

    def getZipAndCountry(self,strips):
        zip_regex = r'\d{5}( \D|$)'
        r = re.compile(zip_regex)
        return list(filter(r.match, strips))

    def getTelefonNumber(self,strips):
        telefon_regex = r'^(\+|\d).+'
        for i,a in enumerate(strips):
            if 'telefon' in a.lower() or 'nummer' in a.lower():
                first_string = re.sub(r'^.*? ',"",a)
                match1 = re.search(telefon_regex, first_string)
                match2 = re.search(telefon_regex, strips[i+1])
                if match1 is not None or match2 is not None:
                    return match1.group(0) if match2 is None else match2.group(0)

# %%
url = "https://www.bechtle.com/impressum"
url1 = "https://www.wirecard.com/de/impressum/"
url2 = "https://www.tu-darmstadt.de/impressum/"
url3 = "https://www.tum.de/die-tum/kontakt-und-anfahrt/impressum"
url4 = "https://www.htw-berlin.de/impressum/"
url5 = "https://www.ikea.com/de/de/customer-service/impressum-pub8c45c280"
url6 = "https://www.lidl.de/c/impressum/s10005238"
url7 = "https://www.tbt.de/" 
url8 = "http://www.diamanttesch.de/" 
url9 =  "http://www.halmosi.de/" 
url10 = "http://www.gross-gabriel.de/" 
url11 = "https://www.norelem.de/" 
url12 = "http://www.heller.biz/" 
url13 = "http://www.kostyrka.com/" 
url14 = "http://fmw-friedrich.de/" 
url15 = "http://www.maw-gmbh.de/" 
url16 = "http://www.nagel.com/" 
url17 = "https://www.blechdesign-zundm.de/" 
url18 = "https://www.hugobeck.com/" 
url19= "https://maschinologen.de/"
# TO DO : 100 urls
urls = [url,url1,url2,url3,url4,url5,url6,url7,url8,url9,url10,url11,url12,url13,url14,url15,url16,url17,url18,url19]

# %%
s = Scraper()
for url in urls:
    write_strips=False
    if url ==url4: # Chnage the url to show the list of elements
        write_strips=False # change true to show list
    s(url,write_strips)
# Out:
# URL : https://www.bechtle.com/impressum
# Email:  ['kontakt@bechtle.com']
# ZIP And Country:  ['74172 Neckarsulm']
# Telefon:  + 49 7132 981-0
# URL : https://www.wirecard.com/de/impressum/
# Email:  ['contact@wirecard.com']
# ZIP And Country:  ['85609 Aschheim']
# Telefon:  +49 89 4424 1200
# URL : https://www.tu-darmstadt.de/impressum/
# Email:  ['presse@tu-darmstadt.de']
# ZIP And Country:  ['64289 Darmstadt']
# Telefon:  06151 / 16-01
# URL : https://www.tum.de/die-tum/kontakt-und-anfahrt/impressum
# Email:  []
# ZIP And Country:  ['80333 München']
# Telefon:  +49 (0) 89 289 01
# URL : https://www.htw-berlin.de/impressum/
# Email:  ['studierendenservice@htw-berlin.de', 'kommunikation@htw-berlin.de.', 'susanne.brandhorst@htw-berlin.de', 'webredaktion@htw-berlin.de', 'webredaktion@htw-berlin.de', 'webmaster@htw-berlin.de', 'bibliothek@htw-berlin.de', 'webredaktion@htw-berlin.de', 'webredaktion@htw-berlin.de', 'webredaktion@htw-berlin.de', 'bibliothek@htw-berlin.de', 'careerservice@htw-berlin.de', 'kontakt-mk@htw-berlin.de', 'mbae@htw-berlin.de', 'studienberatung@htw-berlin.de']
# ZIP And Country:  []
# Telefon:  +49 30 5019 - 0 (Zentrale)
# URL : https://www.ikea.com/de/de/customer-service/impressum-pub8c45c280
# Email:  ['bewerberservice@ikea.com']
# ZIP And Country:  ['65719 Hofheim-Wallau']
# Telefon:  061 92 / 93 99999
# URL : https://www.lidl.de/c/impressum/s10005238
# Email:  ['info@lidl-shop.de', 'kontakt@lidl.de']
# ZIP And Country:  ['74172 Neckarsulm', '74206 Bad Wimpfen']
# Telefon:  0800 - 43 53 361 Kostenfrei. Anrufe nur innerhalb Deutschlands möglich.
# URL : https://www.tbt.de/
# Email:  []
# ZIP And Country:  []
# Telefon:  None
# URL : http://www.diamanttesch.de/
# Email:  ['info@diamanttesch.de']
# ZIP And Country:  []
# Telefon:  None
# URL : http://www.halmosi.de/
# Email:  ['info@halmosi.de', 'info@halmosi.de']
# ZIP And Country:  ['74078 Heilbronn']
# Telefon:  07131-3 90 96-10
# URL : http://www.gross-gabriel.de/
# Email:  []
# ZIP And Country:  ['70599 Stuttgart']
# Telefon:  +49 711 699 656-0
# URL : https://www.norelem.de/
# Email:  ['info@norelem.de', 'info@norelem.de']
# ZIP And Country:  ['01000', '02000', '03000', '04000', '05000', '06000', '07000', '08000', '09000', '10000', '12000', '20000', '21000', '22000', '23000', '24000', '26000', '27000', '28000', '29000', '31000', '32000', '33000', '41000', '42000', '80000', '81000', '82000', '83000', '84000', '85000', '95000', '96000', '97000', '02000 inch', '03000 inch', '04000 inch', '06000 inch', '07000 inch', '27000 inch', '29000 inch', '01000', '02000', '03000', '04000', '05000', '06000', '07000', '08000', '09000', '10000', '12000', '20000', '21000', '22000', '23000', '24000', '26000', '27000', '28000', '29000', '31000', '32000', '33000', '41000', '42000', '80000', '81000', '82000', '83000', '84000', '85000', '95000', '96000', '97000', '02000 inch', '03000 inch', '04000 inch', '06000 inch', '07000 inch', '27000 inch', '29000 inch', '71706 Markgröningen']
# Telefon:  None
# URL : http://www.heller.biz/
# Email:  ['info@heller.biz', 'services@heller.biz', 'info@heller.biz']
# ZIP And Country:  ['72622 Nürtingen']
# Telefon:  None
# URL : http://www.kostyrka.com/
# Email:  []
# ZIP And Country:  []
# Telefon:  None
# URL : http://fmw-friedrich.de/
# Email:  []
# ZIP And Country:  ['73630 Remshalden']
# Telefon:  None
# URL : http://www.maw-gmbh.de/
# Email:  ['info@maw-gmbh.de']
# ZIP And Country:  []
# Telefon:  07031 7376-0 |
# URL : http://www.nagel.com/
# Email:  ['info@nagel.com']
# ZIP And Country:  []
# Telefon:  +49 7022 / 605-0
# URL : https://www.blechdesign-zundm.de/
# Email:  ['info@blechdesign-zundm.de']
# ZIP And Country:  []
# Telefon:  None
# URL : https://www.hugobeck.com/
# Email:  ['info@hugobeck.de']
# ZIP And Country:  []
# Telefon:  None
# URL : https://maschinologen.de/
# Email:  []
# ZIP And Country:  []
# Telefon:  None
